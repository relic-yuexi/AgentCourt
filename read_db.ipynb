# %%
import chromadb

Alicia_Foreman_Client = chromadb.PersistentClient("db/Alicia-Foreman")
Benjamin_Carter_Client = chromadb.PersistentClient("db/Benjamin-Carter")

# %%
Alicia_Foreman_Client.list_collections()

# %%
Benjamin_Carter_Client.list_collections()

# %%
Alicia_Foreman_experience_collection = Alicia_Foreman_Client.get_collection(name="Alicia-Foreman_experience")
Alicia_Foreman_case_collection = Alicia_Foreman_Client.get_collection(name="Alicia-Foreman_case")
Alicia_Foreman_legal_collection = Alicia_Foreman_Client.get_collection(name="Alicia-Foreman_legal")

# %%
Alicia_Foreman_experience_collection.get()
# Out:
# {'ids': ['00db322c-5179-43f0-9132-2a4b796fc216',
#   '027edbec-a789-46ca-8dd3-ad7e709d902d',
#   '06bc3036-0514-42a4-97af-5bcb4e983339',
#   '06d4f5a0-6070-4ca9-8168-f79c8cc69ed9',
#   '07a3e37a-0372-4e45-8d8a-71e6d25f4c51',
#   '0c18aadb-158b-4610-bc28-7627775b66dd',
#   '0d2dc76e-0d80-4ae1-b491-2989a4c8a256',
#   '103c93f2-79a5-4d46-a5d9-720e07a83a7a',
#   '1151159e-a283-47c2-87a6-901c4edb9d2e',
#   '12ca3bb0-a455-47ac-b5ae-379952765249',
#   '140209a0-8163-4f6a-8add-6703353671d8',
#   '169c425d-d851-4677-8bf5-4ca4e090a976',
#   '17c0435a-80bd-4c5c-b22a-51dbd3ef366f',
#   '188f3dd6-cab9-4996-8ee1-7c6f958bf6a9',
#   '198014a6-3cd9-44eb-908a-a2693e535e43',
#   '19b1bc64-9371-4adb-b278-8c45e37ad6f3',
#   '23077830-f8a4-4fb9-9463-ece38a6a2d70',
#   '24252aec-35c5-4ff9-9d61-5bffaebac013',
#   '25667932-5a50-46d4-b886-614231d12eea',
#   '2806798e-bc55-4f6a-a24d-96af505c46d3',
#   '29015563-58b1-4b22-b2a3-461622e1a1e8',
#   '2c27764f-9009-44b2-915d-0153919b57c9',
# ...

# %%
Alicia_Foreman_case_collection.get()
# Out:
# {'ids': ['00015566-e1a6-4893-a6a7-c570cdebf534',
#   '018c7dd2-fc62-4d2d-ba0b-ac862ef21239',
#   '03b29178-f132-4545-a474-709b8dd01e72',
#   '077e5082-77a3-45aa-ae4d-deef38871a23',
#   '088e0520-ef9c-4fe7-acb5-1362e8b3bbb7',
#   '0c6eb17d-8b99-45f4-af37-9c30fa69a988',
#   '0ca0c7f4-a727-4d0c-a43d-12530149bdd6',
#   '0e597799-9915-44dd-abdf-c9b996b5948c',
#   '0f2098b4-ffcc-4d06-aea8-b221a67105df',
#   '0f3a0e3d-1c8c-4a87-988d-1a1440d2dc35',
#   '0fafb7db-1866-450b-b872-0aa424722b09',
#   '14b95186-db59-4c81-8e57-50b2f31d1828',
#   '14d6b900-d5e0-4937-a98f-5342f6cc5bc2',
#   '19570715-5c2c-4f91-b348-b81acb235c58',
#   '1a88387d-37ea-4823-b932-785260055d15',
#   '1e3e3932-a67d-4c71-85c5-35a041e9162c',
#   '1edc8d86-753b-46b9-9bc8-7fc879ee4b9a',
#   '1efcf61c-8220-4cfb-9482-50feee3aa122',
#   '22008c91-2d38-417d-a041-89f06417347d',
#   '25e84a40-9163-4da5-a82d-56f9ec82bdc7',
#   '26075894-5820-4c73-8d54-f8e352303046',
#   '269e8c64-3e7a-4c56-9c3e-2bea1f5f2ead',
# ...

# %%
Alicia_Foreman_legal_collection.get()
# Out:
# {'ids': ['017ca286-1ebf-4f42-81b1-179cdb04afa9',
#   '01d8d15e-72d2-4557-981a-6f30457fb87f',
#   '04ff5a3b-761d-47de-8859-34547dd0dba6',
#   '0a714c71-af2b-4348-8004-2b8b2d167f47',
#   '0bc98886-38a6-4d00-ac9d-1eac8b146d6d',
#   '0be170e1-1757-464f-8e96-b37b66acf47a',
#   '0d1df5ae-9bb2-4072-a063-8dc040bf8b54',
#   '0d260654-b716-4b64-b794-16b37133e1cc',
#   '10615594-8515-4a24-a71b-9544324d5ec1',
#   '10769f9e-b51b-424b-94e7-1410ae5d9d69',
#   '10d26b8a-7a30-4968-aae2-d2a5330fce22',
#   '202b1f54-6a52-408a-98e6-868ccfbbce31',
#   '20da2d72-f13d-4a4a-ab21-44433e778f02',
#   '215d57cd-98ef-49dc-8c69-18ccbc39f19f',
#   '25ad1f1c-4872-4182-ab17-61ee8f24556e',
#   '35e8d096-80ba-41a5-a3d1-931f108529c8',
#   '3abb0b6a-5ea4-424b-a206-d2b7ae22d3ca',
#   '3b78cce2-716c-4f89-af5e-3b5771e64dfa',
#   '3e31a1fb-cd8d-4931-9eaf-3eb28fa40df7',
#   '456c27c4-d443-45dd-b179-15f6631ba861',
#   '474e7125-bd02-40b4-b10b-aefa7cb28339',
#   '49b3414d-7624-4bf6-9b63-e60afbdd0e9d',
# ...
